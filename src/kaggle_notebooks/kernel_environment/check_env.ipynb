# %% [markdown]
# # 実行環境チェック
#
# ノートブックを実行している環境（Kaggle / Colab / VS Code・Cursor / Jupyter / ローカル Python など）を判定し、主要な情報を表示します。

# %%
from kaggle_notebooks.kernel_environment import print_environment_report

info = print_environment_report()
# Out:
# ...
# 実行環境レポート
# ...
#   ランタイム       : Cursor
#   詳細             : Notebook (ipykernel)
#   Kaggle           : No
#   Google Colab     : No
#   Jupyter/IPython  : Yes
#   Jupyter frontend : Cursor
# ------------------------------------------------------------
#   Python           : 3.12.13
#   実行ファイル     : /home/chiba/workspaces/kaggle-notebooks/.venv/bin/python
#   OS / Platform    : Linux-6.6.114.1-microsoft-standard-WSL2-x86_64-with-glibc2.43
#   ホスト名         : PC01
#   作業ディレクトリ : /home/chiba/workspaces/kaggle-notebooks/src/kaggle_notebooks/kernel_environment
# ------------------------------------------------------------
#   追加情報:
#     wsl_distro: WSL01
#     virtual_env: /home/chiba/workspaces/kaggle-notebooks/.venv
#     kernel_connection_file: /run/user/1000/jupyter/runtime/kernel-v32a668dcccb6ed02dd52d0ba71412131883d3b000.json
#     project_root: /home/chiba/workspaces/kaggle-notebooks
# ...
